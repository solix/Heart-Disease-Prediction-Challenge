# %%
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib.pyplot as plt
import seaborn as sns
# Enable inline plotting
# %matplotlib inline

# %%
train_data = pd.read_csv('./data/train_values.csv')
train_label= pd.read_csv('./data/train_labels.csv')
test_data= pd.read_csv('./data/test_values.csv')

# %%
train_data.columns
# Out:
# Index(['patient_id', 'slope_of_peak_exercise_st_segment', 'thal',
#        'resting_blood_pressure', 'chest_pain_type', 'num_major_vessels',
#        'fasting_blood_sugar_gt_120_mg_per_dl', 'resting_ekg_results',
#        'serum_cholesterol_mg_per_dl', 'oldpeak_eq_st_depression', 'sex', 'age',
#        'max_heart_rate_achieved', 'exercise_induced_angina'],
#       dtype='object')

# %%
train_data[:10]
# Out:
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     0z64un                                  1             normal
# 1     ryoo3j                                  2             normal
# 2     yt1s1x                                  1             normal
# 3     l2xjde                                  1  reversible_defect
# 4     oyt4ek                                  3  reversible_defect
# 5     ldukkw                                  1             normal
# 6     2gbyh9                                  2  reversible_defect
# 7     daa9kp                                  2       fixed_defect
# 8     3nwy2n                                  3  reversible_defect
# 9     1r508r                                  2             normal
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
# 5                     130                3                  0
# 6                     150                4                  2
# 7                     150                4                  1
# 8                     170                4                  0
# 9                     120                3                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# 2                                     0                    2
# 3                                     0                    0
# 4                                     0                    2
# 5                                     0                    0
# 6                                     0                    2
# 7                                     0                    2
# 8                                     0                    2
# 9                                     0                    0
#
#    serum_cholesterol_mg_per_dl  oldpeak_eq_st_depression  sex  age  \
# 0                          308                       0.0    1   45
# 1                          214                       1.6    0   54
# 2                          304                       0.0    1   77
# 3                          223                       0.0    1   40
# 4                          270                       4.2    1   59
# 5                          180                       0.0    1   42
# 6                          258                       2.6    0   60
# 7                          276                       0.6    1   57
# 8                          326                       3.4    1   59
# 9                          219                       1.6    0   50
#
#    max_heart_rate_achieved  exercise_induced_angina
# 0                      170                        0
# 1                      158                        0
# 2                      162                        1
# 3                      181                        0
# 4                      145                        0
# 5                      150                        0
# 6                      157                        0
# 7                      112                        1
# 8                      140                        1
# 9                      158                        0

# %%
feature_names = ['slope_of_peak_exercise_st_segment', 'resting_blood_pressure', 'chest_pain_type', 'num_major_vessels', 'fasting_blood_sugar_gt_120_mg_per_dl', 'resting_ekg_results', 'serum_cholesterol_mg_per_dl', 'sex','max_heart_rate_achieved','exercise_induced_angina']

# %%
X = train_data[feature_names]

# %%
Y= train_label['heart_disease_present']

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier

# %%
scaler = preprocessing.MinMaxScaler()
X_scaler = scaler.fit_transform(X)
X_scaler.shape
# Out:
# (180, 10)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scaler, Y,  random_state=0)

# %%
model = SVC(C=1, kernel='rbf', degree=1,coef0=3.0, probability=True)
model2= KNeighborsClassifier(n_neighbors=1, weights='uniform')

# %%
import numpy as np
from sklearn.metrics import log_loss
names = []
scores = []
model.fit(X_train, Y_train)
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)
scores.append(accuracy_score(Y_test, y_pred))
scores.append(log_loss(Y_test,y_pred,eps=1e-15))
tr_split = pd.DataFrame({'Score': scores})
print(tr_split)
# Out:
#       Score
# 0  0.822222
# 1  6.140334

# %%
from keras.utils import np_utils
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation, Conv2D,MaxPooling2D, Flatten
from keras.layers.advanced_activations import ELU
from keras.optimizers import Adam

#Single layer architecture
model = Sequential()
model.add(Dense(32,input_shape=(X_train.shape[1],)))
    # fully connected 2 with dropout
model.add(Dropout(0.2))
model.add(ELU())
model.add(Dense(64,input_shape=(X_train.shape[1],)))
model.add(ELU())
model.add(Dense(64,input_shape=(X_train.shape[1],)))
model.add(ELU())
model.add(Dense(128,input_shape=(X_train.shape[1],)))
model.add(ELU())
model.add(Dense(128,input_shape=(X_train.shape[1],)))
model.add(ELU())
model.add(Dense(128,input_shape=(X_train.shape[1],)))
model.add(ELU())
model.add(Dense(128,input_shape=(X_train.shape[1],)))
model.add(ELU())
model.add(Dense(256,input_shape=(X_train.shape[1],)))
model.add(ELU())
model.add(Dropout(0.4))
model.add(Dense(256,input_shape=(X_train.shape[1],)))
model.add(ELU())
model.add(Dropout(0.4))
model.add(Dense(2))
model.add(Activation('softmax'))
print(model.summary())
model.compile(loss='mse', optimizer=Adam,metrics=['accuracy'])
model.fit(X_train, Y_train, batch_size=128, epochs=100, verbose=1, validation_data=(X_test, Y_test))
loss, accuracy = model.evaluate(X_test,Y_test, verbose=0)
print("Loss : "+str(loss))
print("Accuracy :"+str(accuracy*100.0))
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(random_state=0)
clf.fit(X_train,Y_train)
print(clf.score(X_test,Y_test))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_34 (Dense)             (None, 32)                352
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32)                0
# _________________________________________________________________
# elu_16 (ELU)                 (None, 32)                0
# _________________________________________________________________
# dense_35 (Dense)             (None, 64)                2112
# _________________________________________________________________
# elu_17 (ELU)                 (None, 64)                0
# _________________________________________________________________
# dense_36 (Dense)             (None, 64)                4160
# _________________________________________________________________
# elu_18 (ELU)                 (None, 64)                0
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               8320
# _________________________________________________________________
# elu_19 (ELU)                 (None, 128)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 128)               16512
# _________________________________________________________________
# elu_20 (ELU)                 (None, 128)               0
# _________________________________________________________________
# dense_39 (Dense)             (None, 128)               16512
# _________________________________________________________________
# elu_21 (ELU)                 (None, 128)               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 128)               16512
# _________________________________________________________________
# elu_22 (ELU)                 (None, 128)               0
# _________________________________________________________________
# dense_41 (Dense)             (None, 256)               33024
# _________________________________________________________________
# elu_23 (ELU)                 (None, 256)               0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 256)               65792
# _________________________________________________________________
# elu_24 (ELU)                 (None, 256)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 2)                 514
# _________________________________________________________________
# activation_18 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 163,810
# Trainable params: 163,810
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 135 samples, validate on 45 samples
# Epoch 1/100
# 135/135 [==============================] - 1s 5ms/step - loss: 0.7228 - acc: 0.4889 - val_loss: 0.7162 - val_acc: 0.4444
# Epoch 2/100
# 135/135 [==============================] - 0s 120us/step - loss: 0.7040 - acc: 0.5481 - val_loss: 0.6943 - val_acc: 0.4889
# Epoch 3/100
# 135/135 [==============================] - 0s 171us/step - loss: 0.6816 - acc: 0.5407 - val_loss: 0.7012 - val_acc: 0.4444
# Epoch 4/100
# 135/135 [==============================] - 0s 215us/step - loss: 0.7220 - acc: 0.4296 - val_loss: 0.7077 - val_acc: 0.4222
# Epoch 5/100
# 135/135 [==============================] - 0s 267us/step - loss: 0.6645 - acc: 0.6074 - val_loss: 0.6952 - val_acc: 0.4667
# Epoch 6/100
# 135/135 [==============================] - 0s 154us/step - loss: 0.6812 - acc: 0.5037 - val_loss: 0.6834 - val_acc: 0.6000
# Epoch 7/100
# 135/135 [==============================] - ETA: 0s - loss: 0.6752 - acc: 0.554 - 0s 198us/step - loss: 0.6779 - acc: 0.5556 - val_loss: 0.6852 - val_acc: 0.5333
# Epoch 8/100
# 135/135 [==============================] - 0s 198us/step - loss: 0.6774 - acc: 0.5852 - val_loss: 0.6906 - val_acc: 0.4444
# Epoch 9/100
# 135/135 [==============================] - 0s 126us/step - loss: 0.6919 - acc: 0.5926 - val_loss: 0.6920 - val_acc: 0.4000
# Epoch 10/100
# 135/135 [==============================] - 0s 131us/step - loss: 0.6486 - acc: 0.6667 - val_loss: 0.7067 - val_acc: 0.4000
# Epoch 11/100
# 135/135 [==============================] - 0s 161us/step - loss: 0.6634 - acc: 0.5852 - val_loss: 0.6587 - val_acc: 0.6222
# Epoch 12/100
# 135/135 [==============================] - 0s 161us/step - loss: 0.6431 - acc: 0.6519 - val_loss: 0.6899 - val_acc: 0.4000
# Epoch 13/100
# 135/135 [==============================] - 0s 159us/step - loss: 0.6708 - acc: 0.6148 - val_loss: 0.6640 - val_acc: 0.5333
# Epoch 14/100
# 135/135 [==============================] - ETA: 0s - loss: 0.6267 - acc: 0.664 - 0s 192us/step - loss: 0.6278 - acc: 0.6593 - val_loss: 0.6435 - val_acc: 0.6889
# Epoch 15/100
# 135/135 [==============================] - 0s 168us/step - loss: 0.6326 - acc: 0.6519 - val_loss: 0.6188 - val_acc: 0.7778
# Epoch 16/100
# 135/135 [==============================] - 0s 160us/step - loss: 0.6301 - acc: 0.6815 - val_loss: 0.6144 - val_acc: 0.7778
# Epoch 17/100
# 135/135 [==============================] - 0s 196us/step - loss: 0.6407 - acc: 0.6815 - val_loss: 0.5957 - val_acc: 0.7556
# Epoch 18/100
# 135/135 [==============================] - 0s 186us/step - loss: 0.6541 - acc: 0.6370 - val_loss: 0.5947 - val_acc: 0.8222
# Epoch 19/100
# 135/135 [==============================] - 0s 157us/step - loss: 0.6282 - acc: 0.6815 - val_loss: 0.5932 - val_acc: 0.7778
# Epoch 20/100
# 135/135 [==============================] - 0s 191us/step - loss: 0.6103 - acc: 0.7259 - val_loss: 0.5858 - val_acc: 0.8000
# Epoch 21/100
# 135/135 [==============================] - 0s 219us/step - loss: 0.6296 - acc: 0.6519 - val_loss: 0.6346 - val_acc: 0.5778
# Epoch 22/100
# 135/135 [==============================] - 0s 224us/step - loss: 0.6174 - acc: 0.6444 - val_loss: 0.6464 - val_acc: 0.5333
# Epoch 23/100
# 135/135 [==============================] - 0s 178us/step - loss: 0.6338 - acc: 0.6074 - val_loss: 0.6304 - val_acc: 0.6000
# Epoch 24/100
# 135/135 [==============================] - 0s 136us/step - loss: 0.6127 - acc: 0.6741 - val_loss: 0.6181 - val_acc: 0.6444
# Epoch 25/100
# 135/135 [==============================] - 0s 180us/step - loss: 0.6369 - acc: 0.6741 - val_loss: 0.5949 - val_acc: 0.7333
# Epoch 26/100
# 135/135 [==============================] - 0s 211us/step - loss: 0.5995 - acc: 0.7185 - val_loss: 0.6012 - val_acc: 0.6667
# Epoch 27/100
# 135/135 [==============================] - 0s 163us/step - loss: 0.5645 - acc: 0.7852 - val_loss: 0.5962 - val_acc: 0.6667
# Epoch 28/100
# 135/135 [==============================] - 0s 226us/step - loss: 0.5726 - acc: 0.7556 - val_loss: 0.5657 - val_acc: 0.7778
# Epoch 29/100
# 135/135 [==============================] - ETA: 0s - loss: 0.6000 - acc: 0.742 - 0s 266us/step - loss: 0.5966 - acc: 0.7556 - val_loss: 0.5876 - val_acc: 0.6889
# Epoch 30/100
# 135/135 [==============================] - 0s 243us/step - loss: 0.5653 - acc: 0.7185 - val_loss: 0.5918 - val_acc: 0.6667
# Epoch 31/100
# 135/135 [==============================] - 0s 124us/step - loss: 0.5831 - acc: 0.7556 - val_loss: 0.5782 - val_acc: 0.6889
# Epoch 32/100
# 135/135 [==============================] - 0s 115us/step - loss: 0.5562 - acc: 0.7259 - val_loss: 0.5496 - val_acc: 0.7556
# Epoch 33/100
# 135/135 [==============================] - 0s 138us/step - loss: 0.5804 - acc: 0.7259 - val_loss: 0.5671 - val_acc: 0.7111
# Epoch 34/100
# 135/135 [==============================] - 0s 190us/step - loss: 0.5456 - acc: 0.7704 - val_loss: 0.5720 - val_acc: 0.6667
# Epoch 35/100
# 135/135 [==============================] - 0s 134us/step - loss: 0.5431 - acc: 0.7259 - val_loss: 0.5877 - val_acc: 0.6667
# Epoch 36/100
# 135/135 [==============================] - 0s 121us/step - loss: 0.5486 - acc: 0.7333 - val_loss: 0.5789 - val_acc: 0.6667
# Epoch 37/100
# 135/135 [==============================] - 0s 107us/step - loss: 0.5476 - acc: 0.7630 - val_loss: 0.5887 - val_acc: 0.6667
# Epoch 38/100
# 135/135 [==============================] - 0s 101us/step - loss: 0.5450 - acc: 0.7630 - val_loss: 0.5828 - val_acc: 0.6667
# Epoch 39/100
# 135/135 [==============================] - 0s 135us/step - loss: 0.5783 - acc: 0.6667 - val_loss: 0.5713 - val_acc: 0.6667
# Epoch 40/100
# 135/135 [==============================] - ETA: 0s - loss: 0.5151 - acc: 0.773 - 0s 190us/step - loss: 0.5242 - acc: 0.7704 - val_loss: 0.5398 - val_acc: 0.7333
# Epoch 41/100
# 135/135 [==============================] - 0s 116us/step - loss: 0.5050 - acc: 0.7778 - val_loss: 0.5155 - val_acc: 0.7556
# Epoch 42/100
# 135/135 [==============================] - 0s 111us/step - loss: 0.5468 - acc: 0.7481 - val_loss: 0.5335 - val_acc: 0.7556
# Epoch 43/100
# 135/135 [==============================] - 0s 175us/step - loss: 0.5207 - acc: 0.7630 - val_loss: 0.5745 - val_acc: 0.6667
# Epoch 44/100
# 135/135 [==============================] - 0s 142us/step - loss: 0.5113 - acc: 0.7852 - val_loss: 0.5386 - val_acc: 0.7556
# Epoch 45/100
# 135/135 [==============================] - 0s 148us/step - loss: 0.5064 - acc: 0.7704 - val_loss: 0.5555 - val_acc: 0.7333
# Epoch 46/100
# 135/135 [==============================] - 0s 169us/step - loss: 0.5095 - acc: 0.7556 - val_loss: 0.5883 - val_acc: 0.6667
# Epoch 47/100
# 135/135 [==============================] - 0s 165us/step - loss: 0.5081 - acc: 0.7852 - val_loss: 0.5742 - val_acc: 0.6667
# Epoch 48/100
# 135/135 [==============================] - ETA: 0s - loss: 0.5094 - acc: 0.773 - 0s 180us/step - loss: 0.5157 - acc: 0.7630 - val_loss: 0.5425 - val_acc: 0.7333
# Epoch 49/100
# 135/135 [==============================] - 0s 163us/step - loss: 0.4913 - acc: 0.7852 - val_loss: 0.5728 - val_acc: 0.6889
# Epoch 50/100
# 135/135 [==============================] - 0s 170us/step - loss: 0.4980 - acc: 0.7852 - val_loss: 0.4864 - val_acc: 0.7556
# Epoch 51/100
# 135/135 [==============================] - 0s 186us/step - loss: 0.4843 - acc: 0.8000 - val_loss: 0.5458 - val_acc: 0.7333
# Epoch 52/100
# 135/135 [==============================] - 0s 220us/step - loss: 0.4686 - acc: 0.7926 - val_loss: 0.5336 - val_acc: 0.7333
# Epoch 53/100
# 135/135 [==============================] - 0s 171us/step - loss: 0.4966 - acc: 0.7481 - val_loss: 0.5090 - val_acc: 0.7556
# Epoch 54/100
# 135/135 [==============================] - 0s 183us/step - loss: 0.4228 - acc: 0.8815 - val_loss: 0.4490 - val_acc: 0.8222
# Epoch 55/100
# 135/135 [==============================] - 0s 240us/step - loss: 0.4884 - acc: 0.7778 - val_loss: 0.5086 - val_acc: 0.7556
# Epoch 56/100
# 135/135 [==============================] - 0s 165us/step - loss: 0.4760 - acc: 0.7852 - val_loss: 0.4953 - val_acc: 0.7778
# Epoch 57/100
# 135/135 [==============================] - 0s 128us/step - loss: 0.4708 - acc: 0.8222 - val_loss: 0.5373 - val_acc: 0.7556
# Epoch 58/100
# 135/135 [==============================] - 0s 200us/step - loss: 0.5045 - acc: 0.7630 - val_loss: 0.5521 - val_acc: 0.7333
# Epoch 59/100
# 135/135 [==============================] - 0s 403us/step - loss: 0.4673 - acc: 0.7852 - val_loss: 0.5556 - val_acc: 0.7333
# Epoch 60/100
# 135/135 [==============================] - 0s 176us/step - loss: 0.5339 - acc: 0.7333 - val_loss: 0.5397 - val_acc: 0.7333
# Epoch 61/100
# 135/135 [==============================] - 0s 178us/step - loss: 0.4405 - acc: 0.8370 - val_loss: 0.4811 - val_acc: 0.7556
# Epoch 62/100
# 135/135 [==============================] - 0s 148us/step - loss: 0.4871 - acc: 0.7852 - val_loss: 0.5215 - val_acc: 0.7556
# Epoch 63/100
# 135/135 [==============================] - 0s 135us/step - loss: 0.4621 - acc: 0.8074 - val_loss: 0.5043 - val_acc: 0.7556
# Epoch 64/100
# 135/135 [==============================] - 0s 142us/step - loss: 0.4738 - acc: 0.7778 - val_loss: 0.5148 - val_acc: 0.7556
# Epoch 65/100
# 135/135 [==============================] - 0s 138us/step - loss: 0.4544 - acc: 0.7926 - val_loss: 0.4862 - val_acc: 0.7556
# Epoch 66/100
# 135/135 [==============================] - 0s 131us/step - loss: 0.4501 - acc: 0.8296 - val_loss: 0.5205 - val_acc: 0.7556
# Epoch 67/100
# 135/135 [==============================] - 0s 131us/step - loss: 0.4720 - acc: 0.7630 - val_loss: 0.5820 - val_acc: 0.7111
# Epoch 68/100
# 135/135 [==============================] - 0s 134us/step - loss: 0.4820 - acc: 0.7926 - val_loss: 0.4767 - val_acc: 0.7556
# Epoch 69/100
# 135/135 [==============================] - 0s 164us/step - loss: 0.4343 - acc: 0.8148 - val_loss: 0.5137 - val_acc: 0.7556
# Epoch 70/100
# 135/135 [==============================] - 0s 130us/step - loss: 0.4274 - acc: 0.8074 - val_loss: 0.4811 - val_acc: 0.7333
# Epoch 71/100
# 135/135 [==============================] - 0s 119us/step - loss: 0.4400 - acc: 0.8074 - val_loss: 0.4929 - val_acc: 0.7556
# Epoch 72/100
# 135/135 [==============================] - 0s 130us/step - loss: 0.4269 - acc: 0.8296 - val_loss: 0.5579 - val_acc: 0.7333
# Epoch 73/100
# 135/135 [==============================] - 0s 139us/step - loss: 0.4724 - acc: 0.8074 - val_loss: 0.4838 - val_acc: 0.7778
# Epoch 74/100
# 135/135 [==============================] - 0s 143us/step - loss: 0.4461 - acc: 0.7778 - val_loss: 0.4506 - val_acc: 0.7778
# Epoch 75/100
# 135/135 [==============================] - 0s 144us/step - loss: 0.4533 - acc: 0.7778 - val_loss: 0.4641 - val_acc: 0.7778
# Epoch 76/100
# 135/135 [==============================] - 0s 121us/step - loss: 0.4638 - acc: 0.7852 - val_loss: 0.4645 - val_acc: 0.8222
# Epoch 77/100
# 135/135 [==============================] - 0s 117us/step - loss: 0.4047 - acc: 0.8519 - val_loss: 0.5572 - val_acc: 0.7333
# Epoch 78/100
# 135/135 [==============================] - 0s 121us/step - loss: 0.4707 - acc: 0.7778 - val_loss: 0.4961 - val_acc: 0.7778
# Epoch 79/100
# 135/135 [==============================] - 0s 102us/step - loss: 0.4524 - acc: 0.7778 - val_loss: 0.4493 - val_acc: 0.8000
# Epoch 80/100
# 135/135 [==============================] - 0s 109us/step - loss: 0.4876 - acc: 0.7630 - val_loss: 0.5091 - val_acc: 0.7778
# Epoch 81/100
# 135/135 [==============================] - 0s 116us/step - loss: 0.4398 - acc: 0.8074 - val_loss: 0.5825 - val_acc: 0.6889
# Epoch 82/100
# 135/135 [==============================] - 0s 133us/step - loss: 0.4749 - acc: 0.8148 - val_loss: 0.4856 - val_acc: 0.7778
# Epoch 83/100
# 135/135 [==============================] - 0s 133us/step - loss: 0.4639 - acc: 0.7926 - val_loss: 0.6186 - val_acc: 0.6667
# Epoch 84/100
# 135/135 [==============================] - 0s 124us/step - loss: 0.4102 - acc: 0.8148 - val_loss: 0.6838 - val_acc: 0.6667
# Epoch 85/100
# 135/135 [==============================] - 0s 165us/step - loss: 0.4882 - acc: 0.8074 - val_loss: 0.7261 - val_acc: 0.6222
# Epoch 86/100
# 135/135 [==============================] - 0s 145us/step - loss: 0.4768 - acc: 0.7333 - val_loss: 0.5353 - val_acc: 0.7111
# Epoch 87/100
# 135/135 [==============================] - 0s 123us/step - loss: 0.4563 - acc: 0.7852 - val_loss: 0.5223 - val_acc: 0.7333
# Epoch 88/100
# 135/135 [==============================] - 0s 132us/step - loss: 0.4106 - acc: 0.8296 - val_loss: 0.5239 - val_acc: 0.7556
# Epoch 89/100
# 135/135 [==============================] - 0s 135us/step - loss: 0.4052 - acc: 0.8222 - val_loss: 0.4582 - val_acc: 0.7778
# Epoch 90/100
# 135/135 [==============================] - 0s 115us/step - loss: 0.4355 - acc: 0.8296 - val_loss: 0.4358 - val_acc: 0.8000
# Epoch 91/100
# 135/135 [==============================] - 0s 108us/step - loss: 0.4743 - acc: 0.7778 - val_loss: 0.5110 - val_acc: 0.7778
# Epoch 92/100
# 135/135 [==============================] - 0s 113us/step - loss: 0.4579 - acc: 0.7704 - val_loss: 0.4983 - val_acc: 0.7778
# Epoch 93/100
# 135/135 [==============================] - 0s 111us/step - loss: 0.4653 - acc: 0.7704 - val_loss: 0.5101 - val_acc: 0.7556
# Epoch 94/100
# 135/135 [==============================] - 0s 147us/step - loss: 0.4775 - acc: 0.7704 - val_loss: 0.5044 - val_acc: 0.7556
# Epoch 95/100
# 135/135 [==============================] - 0s 120us/step - loss: 0.4434 - acc: 0.7926 - val_loss: 0.5024 - val_acc: 0.7778
# Epoch 96/100
# 135/135 [==============================] - 0s 127us/step - loss: 0.4339 - acc: 0.7926 - val_loss: 0.7485 - val_acc: 0.6444
# Epoch 97/100
# 135/135 [==============================] - 0s 132us/step - loss: 0.5002 - acc: 0.7185 - val_loss: 0.7888 - val_acc: 0.5556
# Epoch 98/100
# 135/135 [==============================] - ETA: 0s - loss: 0.5447 - acc: 0.726 - 0s 157us/step - loss: 0.5341 - acc: 0.7333 - val_loss: 0.5939 - val_acc: 0.6889
# Epoch 99/100
# 135/135 [==============================] - 0s 319us/step - loss: 0.4653 - acc: 0.7481 - val_loss: 0.5728 - val_acc: 0.7111
# Epoch 100/100
# 135/135 [==============================] - 0s 244us/step - loss: 0.4172 - acc: 0.8296 - val_loss: 0.4974 - val_acc: 0.8000
# Loss : 0.4974180221557617
# Accuracy :80.0000003973643
# 0.6
